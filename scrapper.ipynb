# %%
# !pip install beautifulsoup4
# Out:
# ...
#      |████████████████████████████████| 115 kB 3.5 MB/s eta 0:00:01
# ...

# %%
# !python --version
# Out:
# Python 3.7.3

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.mdbg.net/chinese/dictionary?page=worddict&wdrst=0&wdqb=super'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# results = soup.find('div',class_='hanzi')
# table_elements = soup.findAll('table')[1].findAll('tr')

# %%
# print(table_elements)
print(results)
# Out:
# <div class="hanzi"><a href="#" onclick="aj('62f869',this,'cdqchi',0,'超级'); trackExitLink('inline-cdqchi', 'result-wdb'); return false" title="Show information about all characters"><span class="mpt1">超</span><wbr/><span class="mpt2">级</span><wbr/></a></div>

# %%
table_body=soup.find('tbody')
rows = table_body.find_all('tr')
dict_translations = {}
list_translations = []
for row in rows:
    cols=row.find_all('td')
    cols=[x.text.strip() for x in cols]
    if len(cols) > 1:
        # print (cols)
        # print(len(cols))
        # print(cols[2])
        dict_translations = {'pinyin': cols[0], 'hanzi': cols[1].split('|')[0].strip(), 'eng_meaning': cols[2]}
        # dict_translations['pinyin'] = cols[0]
        # dict_translations['hanzi'] = cols[1].split('|')[0].strip()
        # dict_translations['eng_meaning'] = cols[2]
        list_translations.append(dict_translations)
        # print(dict_translations)
    
# print(list_translations)

# for i in list_translations:
#     print(i)

# %%
for i in list_translations:
    print(i)
# Out:
# {'pinyin': '超级chāo\u200bjí\u200b', 'hanzi': '*超级*', 'eng_meaning': 'super-  / ultra-  / hyper-'}
# {'pinyin': '超chāo\u200b', 'hanzi': '*超*', 'eng_meaning': 'to exceed  / to overtake  / to surpass  / to transcend  / to pass  / to cross  / ultra-  / super-'}
# {'pinyin': '超级杯 Chāo\u200bjí\u200bbēi\u200b', 'hanzi': '*超级杯*', 'eng_meaning': 'Super Cup (various sports)  / Super Bowl (American football championship game)'}
# {'pinyin': '超级杯 Chāo\u200bjí\u200bbēi\u200b', 'hanzi': '*超级杯*', 'eng_meaning': 'Super Cup (various sports)  / Super Bowl (American football championship game)'}
# {'pinyin': '超级碗 Chāo\u200bjí\u200b Wǎn\u200b', 'hanzi': '*超级碗*', 'eng_meaning': 'Super Bowl (American football championship game)'}
# {'pinyin': '真棒zhēn\u200bbàng\u200b', 'hanzi': '*真棒*', 'eng_meaning': 'super!  / really great  / wonderful'}
# {'pinyin': '棒极了bàng\u200bjí\u200ble\u200b', 'hanzi': '*棒极了*', 'eng_meaning': 'super  / excellent'}
# ...
